# %% [markdown]
# The data used for the plots are learned using the master branch without simulating data sparsity.

# %%
import pickle
from sklearn import manifold
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
with open("embeddings.pickle", 'rb') as f:
    [store_embedding, dow_embedding, year_embedding,
     month_embedding, day_embedding, german_states_embedding] = pickle.load(f)

# %%
# Load LabelEncoders
with open("les.pickle", 'rb') as f:
    les = pickle.load(f)
le_store = les[1]
le_dow = les[2]
le_month = les[5]
le_day = les[6]
le_state = les[7]

# %%
list(le_state.classes_)
# Out:
# ['BE', 'BW', 'BY', 'HB,NI', 'HE', 'HH', 'NW', 'RP', 'SH', 'SN', 'ST', 'TH']

# %%
states_names = ['Berlin', 'Baden Wuerttemberg', 'Bayern', 'Niedersachsen/Bremen', 
                'Hessen', 'Hamburg', 'Nordrhein Westfalen', 'Rheinland Pfalz',
                'Schleswig Holstein', 'Sachsen', 'Sachsen Anhalt', 'Thueringen']

# %%
tsne = manifold.TSNE(init='pca', random_state=0, method='exact', perplexity=5, learning_rate=100)
Y = tsne.fit_transform(german_states_embedding)
plt.figure(figsize=(8,8))
plt.scatter(-Y[:, 0], -Y[:, 1])
for i, txt in enumerate(states_names):
    plt.annotate(txt, (-Y[i, 0],-Y[i, 1]), xytext = (-20, 8), textcoords = 'offset points')
plt.savefig('state_embedding.pdf')

# %%
list(le_dow.classes_)
# Out:
# ['1', '2', '3', '4', '5', '6', '7']

# %%
tsne = manifold.TSNE(init='pca', random_state=0, method='exact',perplexity=5, learning_rate=100)
Y = tsne.fit_transform(dow_embedding)
names = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat','Sun']
plt.figure(figsize=(8,8))
plt.scatter(-Y[:, 0], -Y[:, 1])
for i, txt in enumerate(names):
    plt.annotate(txt, (-Y[i, 0],-Y[i, 1]), xytext = (-5, 8), textcoords = 'offset points')
plt.savefig('dow_embedding.png')

# %%
list(le_month.classes_)
# Out:
# ['1', '10', '11', '12', '2', '3', '4', '5', '6', '7', '8', '9']

# %%
tsne = manifold.TSNE(init='pca', random_state=0, method='exact', perplexity=5, learning_rate=100)
Y = tsne.fit_transform(month_embedding)
names = ['Jan', 'Oct', 'Nov', 'Dec', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep']
plt.figure(figsize=(8,8))
plt.scatter(-Y[:, 0], -Y[:, 1])
for i, txt in enumerate(names):
    plt.annotate(txt, (-Y[i, 0],-Y[i, 1]), xytext = (-5, 8), textcoords = 'offset points')
plt.savefig('month_embedding.png')

# %%
tsne = manifold.TSNE(init='pca', random_state=0, method='exact', perplexity=5, learning_rate=100, verbose=2, early_exaggeration=1)
Y = tsne.fit_transform(store_embedding)
names = list(le_store.classes_)
plt.figure(figsize=(20,20))
plt.scatter(-Y[:, 0], -Y[:, 1])
for i, txt in enumerate(names):
    plt.annotate(txt, (-Y[i, 0],-Y[i, 1]))
plt.savefig('store_embedding.png')
# Out:
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1115
# [t-SNE] Computed conditional probabilities for sample 1115 / 1115
# [t-SNE] Mean sigma: 0.116259
# [t-SNE] Iteration 50: error = 2.3433001, gradient norm = 0.0038174 (50 iterations in 1.291s)
# [t-SNE] Iteration 100: error = 1.9419780, gradient norm = 0.0022633 (50 iterations in 1.484s)
# [t-SNE] Iteration 150: error = 1.7663635, gradient norm = 0.0017369 (50 iterations in 1.312s)
# [t-SNE] Iteration 200: error = 1.6635432, gradient norm = 0.0011374 (50 iterations in 1.270s)
# [t-SNE] Iteration 250: error = 1.5940711, gradient norm = 0.0010215 (50 iterations in 1.273s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 1.594071
# [t-SNE] Iteration 300: error = 1.5480766, gradient norm = 0.0005703 (50 iterations in 1.266s)
# [t-SNE] Iteration 350: error = 1.4747679, gradient norm = 0.0004613 (50 iterations in 1.275s)
# [t-SNE] Iteration 400: error = 1.4214891, gradient norm = 0.0003719 (50 iterations in 1.499s)
# [t-SNE] Iteration 450: error = 1.3854754, gradient norm = 0.0002859 (50 iterations in 1.403s)
# [t-SNE] Iteration 500: error = 1.3607482, gradient norm = 0.0002332 (50 iterations in 1.315s)
# [t-SNE] Iteration 550: error = 1.3429152, gradient norm = 0.0001860 (50 iterations in 1.354s)
# [t-SNE] Iteration 600: error = 1.3296784, gradient norm = 0.0001591 (50 iterations in 1.399s)
# [t-SNE] Iteration 650: error = 1.3194028, gradient norm = 0.0001368 (50 iterations in 1.561s)
# [t-SNE] Iteration 700: error = 1.3113097, gradient norm = 0.0001197 (50 iterations in 1.391s)
# [t-SNE] Iteration 750: error = 1.3046969, gradient norm = 0.0001069 (50 iterations in 1.621s)
# [t-SNE] Iteration 800: error = 1.2994200, gradient norm = 0.0000945 (50 iterations in 1.330s)
# [t-SNE] Iteration 850: error = 1.2950508, gradient norm = 0.0000869 (50 iterations in 1.319s)
# [t-SNE] Iteration 900: error = 1.2912975, gradient norm = 0.0000852 (50 iterations in 1.336s)
# [t-SNE] Iteration 950: error = 1.2877492, gradient norm = 0.0000823 (50 iterations in 1.352s)
# [t-SNE] Iteration 1000: error = 1.2845502, gradient norm = 0.0000782 (50 iterations in 1.426s)
# [t-SNE] KL divergence after 1000 iterations: 1.284550
