# %%
import numpy
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
distances = numpy.loadtxt(open("distances.csv","r"),delimiter=" ")

# %%
distances
# Out:
# array([[  2.33808707e+03,   1.69515000e+00],
#        [  2.20209744e+03,   1.50831000e+00],
#        [  8.55184852e+02,   1.73432000e+00],
#        ...,
#        [  4.43946463e+03,   2.08118000e+00],
#        [  2.48838639e+03,   2.00538000e+00],
#        [  2.36236492e+03,   1.53081000e+00]])

# %%
plt.figure(figsize=(8,6))
plt.xlim([0, 20000])
plt.xlabel('distance in metric space')
plt.ylabel('distance in embedding space')
plt.scatter(distances[:, 0], distances[:, 1])
plt.savefig('distance.pdf')
